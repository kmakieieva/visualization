# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Set random seed for reproducibility
np.random.seed(613)
   # Create array [0 - 49]
x = np.arange(50)
# Generate 50 random integers between 0 and 99
y = np.random.randint(0,100,50)

# Create figure and axes (5x3 inches)
fig, ax = plt.subplots(figsize = (5,3))
#fig, ax = plt.subplots(figsize = (5,3))
#ax.scatter(x,y)
#ax.bash(x,y)
#ax.plot(x,y)
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
# Font style for title
font1 = {'family':'sans-serif','color':'blue','size':20}
# Font style for axis labels
font2 = {'family':'monospace','color':'green','size':14}

fig, ax = plt.subplots(figsize = (5,3))
# Plot line graph
ax.plot(x,y)
# Set title with custom font
ax.set_title('Total growth over time', fontdict =font1)
# Set y axis label with custom font
ax.set_ylabel('Total growth', fontdict =font2)
# Set x axis label with custom font
ax.set_xlabel('Years since start', fontdict =font2)
fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(5,3))
# Create custom scatter plot
ax.scatter(x,y,marker = '*', color = 'indigo')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y,marker = '*', color = 'indigo', linestyle = '--', linewidth = 2)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y,
        marker = '*',
        markersize = 12,
        color = '#7425b9',
        linestyle = '--',
        linewidth = 2,
        markeredgecolor = '#fa9359',
        markerfacecolor = '#000000')
ax.grid(color = 'blue', linewidth = 2, linestyle = 'dotted')

# %%
import seaborn as sns

df = sns.load_dataset('iris')

sns.set_style("white")
sns.kdeplot(x=df.sepal_width, y=df.sepal_length)
plt.show()

# %%
sns.set_style("white")
sns.kdeplot(x=df.sepal_width, y=df.sepal_length, cmap="Reds", fill=True)
plt.show()
